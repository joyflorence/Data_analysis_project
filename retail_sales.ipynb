# %%
from Datascrubber import Datacleaning
datacleaner = Datacleaning()

# %%
datacleaner.read_data('retail_sales_dataset.csv')
# Out:
# Data Description:
#
# The file retail_sales_dataset has 1000 Rows and 9 Columns
#
# Categorical Columns(4): Date, Customer ID, Gender, Product Category
# Continuous Columns(5): Transaction ID, Age, Quantity, Price per Unit, Total Amount
#
# Missing Values:0
#    Transaction ID        Date Customer ID  Gender  Age Product Category  \
# 0               1  2023-11-24     CUST001    Male   34           Beauty
# 1               2  2023-02-27     CUST002  Female   26         Clothing
# 2               3  2023-01-13     CUST003    Male   50      Electronics
# 3               4  2023-05-21     CUST004    Male   37         Clothing
# 4               5  2023-05-06     CUST005    Male   30           Beauty
#
#    Quantity  Price per Unit  Total Amount
# 0         3              50           150
# 1         2             500          1000
# 2         1              30            30
# 3         1             500           500
# 4         2              50           100

# %%
datacleaner.outliers()

# %%
datacleaner.cont_cols()
# Out:
#    Transaction ID  Age  Quantity  Price per Unit  Total Amount
# 0               1   34         3              50           150
# 1               2   26         2             500          1000
# 2               3   50         1              30            30
# 3               4   37         1             500           500
# 4               5   30         2              50           100

# %%
datacleaner.distributions()

# %%
datacleaner.cont_cols().columns
# Out:
# Index(['Transaction ID', 'Age', 'Quantity', 'Price per Unit', 'Total Amount'], dtype='object')

# %%
datacleaner.cont_to_cont('Transaction ID','Total Amount')
# Out:
# The correlation between Transaction ID and Total Amount is: -0.07503432030192904

# %%
datacleaner.cat_cols().columns
# Out:
# Index(['Date', 'Customer ID', 'Gender', 'Product Category'], dtype='object')

# %%
datacleaner.cont_to_cat('Total Amount','Customer ID')
# Out:
# Customer ID is correlated with Total Amount

# %%
datacleaner.cat_to_cat('Gender','Product Category')
# Out:
# Chi_square value: 1.673837085800602
# p value: 0.43304287262068974
# degrees of freedom: 2
# Gender is not correlated with Product Category

# %%
datacleaner.corr_matrix()

# %%
import numpy as np 
import pandas as pd 
from mlxtend.frequent_patterns import apriori, association_rules

# %%
retail_sales = pd.read_csv('retail_sales_dataset.csv')
retail_sales.head()
# Out:
#    Transaction ID        Date Customer ID  Gender  Age Product Category  \
# 0               1  2023-11-24     CUST001    Male   34           Beauty
# 1               2  2023-02-27     CUST002  Female   26         Clothing
# 2               3  2023-01-13     CUST003    Male   50      Electronics
# 3               4  2023-05-21     CUST004    Male   37         Clothing
# 4               5  2023-05-06     CUST005    Male   30           Beauty
#
#    Quantity  Price per Unit  Total Amount
# 0         3              50           150
# 1         2             500          1000
# 2         1              30            30
# 3         1             500           500
# 4         2              50           100

# %%
retail_sales.columns
# Out:
# Index(['Transaction ID', 'Date', 'Customer ID', 'Gender', 'Age',
#        'Product Category', 'Quantity', 'Price per Unit', 'Total Amount'],
#       dtype='object')
